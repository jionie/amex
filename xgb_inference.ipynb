# %%
import os
import gc
from joblib import dump, load
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb

# %% [markdown]
# # load files

# %%
test = pd.read_parquet("../input/test_base_normalized.parquet")

# %%
submission = pd.read_csv("../input/sample_submission.csv")
submission["customer_ID_16"] = submission["customer_ID"].str[-16:]
    
hex_to_int = lambda x: int(x, 16)
submission[["customer_ID_16"]] = submission[["customer_ID_16"]].applymap(lambda x: int(x, 16))
submission["customer_ID_16"] = submission["customer_ID_16"].astype("int64")

# %%
test.head()
# Out:
#                       P_2_nanstd  P_2_nanmin  P_2_nanmax  P_2_last  \
# customer_ID
# -9223277493928322471    0.051276    0.255823    0.385323  0.348086
# -9223220269070810982    0.194608    0.569106    0.990750  0.587732
# -9223219380479694318    0.067203    0.373986    0.620500  0.508076
# -9223202973368451495    0.114133    0.097991    0.459981  0.459981
# -9223190037945288673    0.102632    1.140431    1.418187  1.233938
#
#                       D_39_nanstd  D_39_nanmin  D_39_nanmax  D_39_last  \
# customer_ID
# -9223277493928322471     0.030696    -0.569252    -0.458575  -0.569252
# -9223220269070810982     0.000000    -0.569252    -0.569252  -0.569252
# -9223219380479694318     0.066312    -0.569252    -0.347897  -0.569252
# -9223202973368451495     0.244931    -0.569252     0.316168  -0.569252
# -9223190037945288673     0.822813    -0.569252     1.644298   1.644298
#
#                       B_1_nanstd  B_1_nanmin  ...  D_63_nunique  D_64_count  \
# customer_ID                                   ...
# -9223277493928322471    0.047913   -0.588713  ...             1          13
# -9223220269070810982    0.061270   -0.588980  ...             1          13
# -9223219380479694318    0.033638   -0.597878  ...             1          13
# -9223202973368451495    0.015040   -0.596622  ...             1          13
# -9223190037945288673    0.181185   -0.573914  ...             1          13
#
#                       D_64_last  D_64_nunique  D_66_count  D_66_last  \
# customer_ID
# -9223277493928322471          2             1           0          1
# -9223220269070810982          2             1           0          1
# -9223219380479694318          0             1           0          1
# -9223202973368451495          0             1           0          1
# -9223190037945288673          0             2           0          1
#
#                       D_66_nunique  D_68_count  D_68_last  D_68_nunique
# customer_ID
# -9223277493928322471             0          13          1             2
# -9223220269070810982             0          13          5             1
# -9223219380479694318             0          13          5             1
# -9223202973368451495             0          13          5             1
# -9223190037945288673             0          13          2             2
#
# [5 rows x 1449 columns]

# %%
submission.head()
# Out:
#                                          customer_ID  prediction  \
# 0  00000469ba478561f23a92a868bd366de6f6527a684c9a...           0
# 1  00001bf2e77ff879fab36aa4fac689b9ba411dae63ae39...           0
# 2  0000210045da4f81e5f122c6bde5c2a617d03eef67f82c...           0
# 3  00003b41e58ede33b8daf61ab56d9952f17c9ad1c3976c...           0
# 4  00004b22eaeeeb0ec976890c1d9bfc14fd9427e98c4ee9...           0
#
#         customer_ID_16
# 0  8717704911770597815
# 1  4783907996972277493
# 2  4616129756878093544
# 3 -1916505587365783916
# 4  7583456031722841431

# %% [markdown]
# # config

# %%
n_folds = 5
seed = 42

exclude_features = []

exclude_features += [
    "customer_ID", 
    "target",
    "number_of_observations",
]
features = [col for col in test.columns if col not in exclude_features]

# %% [markdown]
# # inference

# %%
def inference(df):
    
    preds = None
    
    for fold in range(n_folds):
        
        print("inference seed {} fold {}".format(seed, fold))
        
        x_test = df[features]
        xgb_test = xgb.DMatrix(data=x_test)

        model = xgb.Booster()
        model.load_model("../ckpt/base_normalize/xgb_{}_{}.xgb".format(fold, seed))
        
        if preds is None:
            preds = model.predict(xgb_test) / n_folds
        else:
            preds += model.predict(xgb_test) / n_folds

        del x_test, xgb_test, model
        _ = gc.collect()
        
    return preds

# %%
preds = inference(test)
# Out:
# inference seed 42 fold 0
# inference seed 42 fold 1
# inference seed 42 fold 2
# inference seed 42 fold 3
# inference seed 42 fold 4

# %%
test_prediction = pd.DataFrame({"customer_ID_16" : test.index, "prediction_orig" : preds})

# %%
test_prediction
# Out:
#              customer_ID_16  prediction_orig
# 0      -9223277493928322471         0.021320
# 1      -9223220269070810982         0.012178
# 2      -9223219380479694318         0.023670
# 3      -9223202973368451495         0.072177
# 4      -9223190037945288673         0.009027
# ...                     ...              ...
# 924616  9223311419908670169         0.010892
# 924617  9223316227884056852         0.046076
# 924618  9223317482642190638         0.002591
# 924619  9223341949877516615         0.006378
# 924620  9223363807913010481         0.053857
#
# [924621 rows x 2 columns]

# %%
submission = submission.merge(test_prediction, on="customer_ID_16")

# %%
submission = submission.drop(["customer_ID_16", "prediction"], axis=1).rename(columns={"prediction_orig" : "prediction"})

# %%
submission.head()
# Out:
#                                          customer_ID  prediction
# 0  00000469ba478561f23a92a868bd366de6f6527a684c9a...    0.077972
# 1  00001bf2e77ff879fab36aa4fac689b9ba411dae63ae39...    0.001503
# 2  0000210045da4f81e5f122c6bde5c2a617d03eef67f82c...    0.159563
# 3  00003b41e58ede33b8daf61ab56d9952f17c9ad1c3976c...    0.296909
# 4  00004b22eaeeeb0ec976890c1d9bfc14fd9427e98c4ee9...    0.913397

# %%
submission.to_csv("submission_base_normalized.csv", index=False)
